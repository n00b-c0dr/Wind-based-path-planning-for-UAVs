# %%
import environment
import Dynamic_programming

# %%
env=environment.WindField()

# %% [markdown]
# ## Initial State

# %%
env.render()

# %% [markdown]
# ## Uniform Windfield

# %% [markdown]
# ### Non-stochastic

# %%
uniform = env.uniform_windfield(stochastic=False)
env.plot_windfield(uniform)

# %% [markdown]
# ### Stochastic

# %%
uniform = env.uniform_windfield()
env.plot_windfield(uniform)

# %% [markdown]
# The windfield images used in the report are not stochastic, they were just used for cleaner display which are similar to image in the paper.

# %%
env.uniform_windfield()
policy=Dynamic_programming.value_iteration(env)

# %%
Dynamic_programming.run_policy(env,policy)

# %% [markdown]
# ## Non-uniform Windfield 1

# %% [markdown]
# ### Non-stochastic

# %%
non_uniform = env.non_uniform_windfield1(stochastic=False)
env.plot_windfield(non_uniform)

# %% [markdown]
# ### Stochastic

# %%
non_uniform = env.non_uniform_windfield1()
env.plot_windfield(non_uniform)

# %%
env.non_uniform_windfield1()
policy=Dynamic_programming.value_iteration(env)

# %%
Dynamic_programming.run_policy(env,policy)

# %% [markdown]
# ## Non uniform Windfield 2

# %% [markdown]
# ### Stochastic

# %%
non_uniform_windfield = env.non_uniform_windfield2()
env.plot_windfield(non_uniform_windfield)

# %%
env.non_uniform_windfield2
policy=Dynamic_programming.value_iteration(env)

# %%
Dynamic_programming.run_policy(env,policy)
